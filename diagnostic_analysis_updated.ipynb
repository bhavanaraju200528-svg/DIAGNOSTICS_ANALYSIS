# %%
import pandas as pd
import statistics
import matplotlib.pyplot as plt
member_names=["aman","riya","karan","sneha","rahul"]
ages = [22,25,26,27]
workout_hours = [2,1,5,2.5,1,3]
colories_burned = [500,600,700,800,900]
print(" finesss center dataset")
l = len(member_names)
for i in range(l-1):
    print(member_names[i],ages[i],workout_hours[i],colories_burned[i])
#mean workout hours
average_workout = sum(workout_hours)/len(workout_hours)
print("\n average workout hours =", average_workout)
#max calories
max_calories = max(colories_burned)
print("\n max calories =", max_calories)
#min calories
min_calories = min(colories_burned)
print("\n min calories =", min_calories)
# median
median_calories = statistics.median(colories_burned)
print("\n median calories =", median_calories)
#mode
mode_calories = statistics.mode(colories_burned)
print("\n mode calories =", mode_calories)

std_dev = statistics.stdev(colories_burned)
print("\n standard deviation =", std_dev)

index = colories_burned.index(max_calories)
print("most active member",member_names[index])
index = colories_burned.index(min_calories)
print("least active member",member_names[index])

plt.bar(member_names,colories_burned)
plt.xlabel("member names")
plt.ylabel("colories burned")
plt.title("fitness center")
plt.show()
# Out:
#  finesss center dataset
# aman 22 2 500
# riya 25 1 600
# karan 26 5 700
# sneha 27 2.5 800
#
#  average workout hours = 2.4166666666666665
#
#  max calories = 900
#
#  min calories = 500
#
#  median calories = 700
#
#  mode calories = 500
#
#  standard deviation = 158.11388300841898
# most active member rahul
# least active member aman

# %%
import pandas as pd
import statistics
import matplotlib.pyplot as plt

# Read uploaded CSV file
df = pd.read_csv('/content/gym_members_exercise_tracking_transformed.csv')

# Display first 5 rows
print("Fitness Center Dataset")
print(df.head())

# Extract required columns
member_names = df['Gender']          # You can replace with Name column if available
ages = df['Age']
df['Session_Duration (hours)'] = df['Session_Duration (hours)'].astype(int)
calories_burned = df['Calories_Burned']

# Mean workout hours
average_workout = workout_hours.mean()
print("\nAverage workout hours =", average_workout)

# Max calories
max_calories = calories_burned.max()
print("\nMax calories =", max_calories)

# Min calories
min_calories = calories_burned.min()
print("\nMin calories =", min_calories)

# Median calories
median_calories = statistics.median(calories_burned)
print("\nMedian calories =", median_calories)

# Mode calories
mode_calories = statistics.mode(calories_burned)
print("\nMode calories =", mode_calories)

# Standard deviation
std_dev = statistics.stdev(calories_burned)
print("\nStandard deviation =", std_dev)

# Most active member
index = calories_burned.idxmax()
print("\nMost active member:")
print(df.loc[index])

# Least active member
index = calories_burned.idxmin()
print("\nLeast active member:")
print(df.loc[index])

# Bar chart
plt.figure(figsize=(10,5))
plt.bar(member_names[:10], calories_burned[:10])

plt.xlabel("Gender")
plt.ylabel("Calories Burned")
plt.title("Fitness Center Analysis of genders and calories burned")
plt.show()
# Bar chart
plt.figure(figsize=(10,5))
plt.bar(member_names[:10], workout_hours[:10])

plt.xlabel("Gender")
plt.ylabel("workout hours ")
plt.title("Fitness Center Analysis of gender and workout hours")
plt.show()
# Out:
# Fitness Center Dataset
#    Age  Gender  Session_Duration (hours)  Calories_Burned Workout_Type    BMI
# 0   56    Male                      1.69             1313         Yoga  30.20
# 1   46  Female                      1.30              883         HIIT  32.00
# 2   32  Female                      1.11              677       Cardio  24.71
# 3   25    Male                      0.59              532     Strength  18.41
# 4   38    Male                      0.64              556     Strength  14.39
#
# Average workout hours = 1.2564234326824255
#
# Max calories = 1783
#
# Min calories = 303
#
# Median calories = 893
#
# Mode calories = 883
#
# Standard deviation = 272.64151645225877
#
# Most active member:
# Age                               32
# Gender                          Male
# Session_Duration (hours)           1
# Calories_Burned                 1783
# Workout_Type                Strength
# BMI                            24.36
# Name: 910, dtype: object
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# dataset
item_name = ["puma", "nike","gucci" , "channel","lv"]
internet_speed = [20,25,30,22,80]
payment_failure = [0,1,4,2,0]
delivery_charges = [50,60,0,50,70]
purchase_completed =["true","false","true","false","true"]

# printing dataset
l = len(item_name)
for i in range(l-1):
    print(item_name[i],internet_speed[i],payment_failure[i],delivery_charges[i],purchase_completed[i])
print("\nTOTAL ABANDNMENT-customer satisfaction based on dataset \n")
count = 0
#total abandnmentt
for i in range(l-1):
   print(item_name[i],internet_speed[i],payment_failure[i],delivery_charges[i],purchase_completed[i])
   if (internet_speed[i] < 10):
    count = 1
   if (payment_failure[i] >=2):
      count = 1
   if(delivery_charges[i] >=70):
      count = 1
   if(purchase_completed[i] == "false"):
      count = 1
   if (count == 0):
     print("the customer is satisfied \n")
   else:
    print("the customer is not satisfied \n")
 #INTERNET DIAGNOSTICE
sat =0
nsat =0
print("INTERNET DIAGNOSTICE")
for i in range(l-1):
   print(item_name[i],internet_speed[i])
   if (internet_speed[i] < 10):
    print("the customer is satisfied \n")
    sat = sat + 1
   else:
    print("the customer is not satisfied \n")
    nsat = nsat + 1
plt.bar(["Satisfied","Unsatisfied"], [sat, nsat])

plt.xlabel("Customer Status")
plt.ylabel("Count")
plt.title("Internet Diagnostic")

plt.show()
#payment diagnostics
sat1 =0
nsat1 =0
print("payment diagnostice")
for i in range(l-1):
   print(item_name[i],payment_failure[i])
   if (payment_failure[i] <=2):
    print("the customer is satisfied \n")
    sat1 = sat1 + 1
   else:
    print("the customer is not satisfied \n")
    nsat1 = nsat1 + 1
plt.bar(["Satisfied","Unsatisfied"], [sat1, nsat1])

plt.xlabel("Customer Status")
plt.ylabel("Count")
plt.title("Payment Diagnostic")

plt.show()

#dilivery diagnostics
sat2 =0
nsat2 =0
print("dilivery diagnostice")
for i in range(l-1):
   print(item_name[i],delivery_charges[i])
   if (delivery_charges[i] <=70):
    print("the customer is satisfied \n")
    sat2 = sat2 + 1
   else:
    print("the customer is not satisfied \n")
    nsat2 = nsat2 + 1
plt.bar(["Satisfied","Unsatisfied"], [sat2, nsat2])

plt.xlabel("Customer Status")
plt.ylabel("Count")
plt.title("Delivery Diagnostic")

plt.show()
# Out:
# puma 20 0 50 true
# nike 25 1 60 false
# gucci 30 4 0 true
# channel 22 2 50 false
#
# TOTAL ABANDNMENT-customer satisfaction based on dataset
#
# puma 20 0 50 true
# the customer is satisfied
#
# nike 25 1 60 false
# the customer is not satisfied
#
# gucci 30 4 0 true
# the customer is not satisfied
#
# channel 22 2 50 false
# the customer is not satisfied
#
# INTERNET DIAGNOSTICE
# puma 20
# the customer is not satisfied
#
# nike 25
# the customer is not satisfied
#
# gucci 30
# the customer is not satisfied
#
# channel 22
# the customer is not satisfied
# payment diagnostice
# puma 0
# the customer is satisfied
#
# nike 1
# the customer is satisfied
#
# gucci 4
# the customer is not satisfied
#
# channel 2
# the customer is satisfied
# dilivery diagnostice
# puma 50
# the customer is satisfied
#
# nike 60
# the customer is satisfied
#
# gucci 0
# the customer is satisfied
#
# channel 50
# the customer is satisfied

# %%
import pandas as pd
import matplotlib.pyplot as plt

# READ DATASET FROM CSV FILE LINK


df = pd.read_csv('/content/Sales Transaction v.4a.csv')

print("SALES TRANSACTION DATASET\n")

# selecting columns
product = df['ProductName']
price = df['Price']
quantity = df['Quantity']
country = df['Country']

# length
l = len(df)



print("\nDIAGNOSTIC ANALYSIS\n")

sat = 0
nsat = 0

# diagnostic analysis
for i in range(10):

    print(product[i], price[i], quantity[i], country[i])

    if (price[i] > 10 and quantity[i] > 5):

        print("Sales performance is GOOD\n")
        sat = sat + 1

    else:

        print("Sales performance is BAD\n")
        nsat = nsat + 1

# BAR GRAPH
plt.bar(["Good Sales", "Bad Sales"], [sat, nsat])

plt.xlabel("Sales Status")
plt.ylabel("Count")
plt.title("Sales Diagnostic Analysis")

plt.show()

# COUNTRY WISE ANALYSIS
print("\nCOUNTRY ANALYSIS\n")

country_count = df['Country'].value_counts()

print(country_count)

# COUNTRY GRAPH
country_count.head(5).plot(kind='bar')

plt.xlabel("Country")
plt.ylabel("Transactions")
plt.title("Top Countries by Sales")

plt.show()
# Out:
# SALES TRANSACTION DATASET
#
#
# DIAGNOSTIC ANALYSIS
#
# Set Of 2 Wooden Market Crates 21.47 12 United Kingdom
# Sales performance is GOOD
#
# Christmas Star Wish List Chalkboard 10.65 36 United Kingdom
# Sales performance is GOOD
#
# Storage Tin Vintage Leaf 11.53 12 United Kingdom
# Sales performance is GOOD
#
# Tree T-Light Holder Willie Winkie 10.65 12 United Kingdom
# Sales performance is GOOD
#
# Set Of 4 Knick Knack Tins Poppies 11.94 6 United Kingdom
# Sales performance is GOOD
#
# Bag 500g Swirly Marbles 10.65 24 United Kingdom
# Sales performance is GOOD
#
# Joy Wooden Block Letters 11.53 18 United Kingdom
# Sales performance is GOOD
#
# Peace Wooden Block Letters 12.25 12 United Kingdom
# Sales performance is GOOD
#
# T-Light Holder Hanging Lace 10.65 12 United Kingdom
# Sales performance is GOOD
#
# T-Light Holder White Lace 10.55 24 United Kingdom
# Sales performance is GOOD
# COUNTRY ANALYSIS
#
# Country
# United Kingdom          415304
# France                    8836
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# READ DATASET
df = pd.read_csv('/content/ecommerce_dataset_updated.csv')

print("ECOMMERCE DATASET\n")

# SELECTING COLUMNS
category = df['Category']
price = df['Price (Rs.)']
discount = df['Discount (%)']
final_price = df['Final_Price(Rs.)']
payment_method = df['Payment_Method']



print("\nDIAGNOSTIC ANALYSIS\n")

sat = 0
nsat = 0

# DIAGNOSTIC ANALYSIS
for i in range(10):

    print(category[i], price[i], discount[i], final_price[i], payment_method[i])

    # CONDITIONS
    if (price[i] > 200 and discount[i] >= 20):

        print("Customer purchase is GOOD\n")
        sat = sat + 1

    else:

        print("Customer purchase is LOW\n")
        nsat = nsat + 1

# BAR GRAPH
plt.bar(["Good Purchase", "Low Purchase"], [sat, nsat])

plt.xlabel("Purchase Status")
plt.ylabel("Count")
plt.title("Ecommerce Diagnostic Analysis")

plt.show()

# CATEGORY ANALYSIS
print("\nCATEGORY ANALYSIS\n")

category_count = df['Category'].value_counts()

print(category_count)

# CATEGORY GRAPH
category_count.plot(kind='bar')

plt.xlabel("Category")
plt.ylabel("Number of Purchases")
plt.title("Category Wise Purchases")

plt.show()

# PAYMENT METHOD ANALYSIS
print("\nPAYMENT METHOD ANALYSIS\n")

payment_count = df['Payment_Method'].value_counts()

print(payment_count)

# PIE CHART
payment_count.plot(kind='pie', autopct='%1.1f%%')

plt.title("Payment Method Distribution")

plt.ylabel("")

plt.show()
# Out:
# ECOMMERCE DATASET
#
# Sports 36.53 15 31.05 Net Banking
# Clothing 232.79 20 186.23 Net Banking
# Sports 317.02 25 237.76 Credit Card
# Toys 173.19 25 129.89 UPI
# Beauty 244.8 20 195.84 Net Banking
# Books 241.86 50 120.93 UPI
# Toys 76.91 5 73.06 Credit Card
# Sports 213.23 20 170.58 Net Banking
# Sports 379.81 5 360.82 Credit Card
# Home & Kitchen 415.36 50 207.68 Net Banking
#
# DIAGNOSTIC ANALYSIS
#
# Sports 36.53 15 31.05 Net Banking
# Customer purchase is LOW
#
# Clothing 232.79 20 186.23 Net Banking
# Customer purchase is GOOD
#
# Sports 317.02 25 237.76 Credit Card
# Customer purchase is GOOD
#
# Toys 173.19 25 129.89 UPI
# Customer purchase is LOW
#
# Beauty 244.8 20 195.84 Net Banking
# Customer purchase is GOOD
#
# Books 241.86 50 120.93 UPI
# Customer purchase is GOOD
#
# Toys 76.91 5 73.06 Credit Card
# Customer purchase is LOW
#
# Sports 213.23 20 170.58 Net Banking
# Customer purchase is GOOD
#
# Sports 379.81 5 360.82 Credit Card
# Customer purchase is LOW
#
# ...

# %%
from typing_extensions import final
import pandas as pd
import matplotlib.pyplot as plt
#dataset

water_consumption = [ 10,30, 60, 90,120]
day = [1,2,3,4,5,6,7]
tank_capacity = 150
#average water consumed
average_water_consumed = sum(water_consumption)/len(water_consumption)
print("\n average water consumed =", average_water_consumed)

# total water consumed in a day
print("total water consumed in a day ")
for i in range(len(water_consumption)):
  print(day[i],water_consumption[i])


# water usage increased
count = []  # create empty list first
l = len(water_consumption)
for i in range((l - 1)):
    count.append(abs(water_consumption[i + 1] - water_consumption[i]))
    print(count[i])

#sum of daily incresed water

total = sum(count)
average = total / len(count)

print("Sum of daily incresd water:", total)
print("Average of daily incresed water :", average)

# predictions
final_value = water_consumption[l-1]
print(final_value)
final_value = final_value + average
if (final_value < tank_capacity):
# Out:
#   File "/tmp/ipykernel_966/2921329067.py", line 38
#     if (final_value < tank_capacity):
#                                      ^
# SyntaxError: incomplete input

# %%
from typing_extensions import final
import pandas as pd
import matplotlib.pyplot as plt
#dataset

water_consumption = [ 10,30, 60,90,120,150,180]
day = [1,2,3,4,5,6,7]
tank_capacity = 220
#average water consumed
average_water_consumed = sum(water_consumption)/len(water_consumption)
print("\n average water consumed =", average_water_consumed)

# total water consumed in a day
print("total water consumed in a day ")
for i in range(len(water_consumption)):
  print(day[i],water_consumption[i])


# water usage increased
count = []  # create empty list first
l = len(water_consumption)
for i in range((l - 1)):
    count.append(abs(water_consumption[i + 1] - water_consumption[i]))
    print(count[i])

#sum of daily incresed water

total = sum(count)
average = total / len(count)

print("Sum of daily incresd water:", total)
print("Average of daily incresed water :", average)

# predictions
final_value = water_consumption[l-1]
print(final_value)
final_value = final_value + average
if (final_value < tank_capacity):
  print("there is NO water shortage in the tank")
else:
  print("there is water shortage in the tank")



plt.plot(day, water_consumption)

plt.xlabel("Day")
plt.ylabel("Water Consumed")
plt.title("Water Consumption Over Days")

plt.show()
# Out:
#  average water consumed = 91.42857142857143
# total water consumed in a day
# 1 10
# 2 30
# 3 60
# 4 90
# 5 120
# 6 150
# 7 180
# 20
# 30
# 30
# 30
# 30
# 30
# Sum of daily incresd water: 170
# Average of daily incresed water : 28.333333333333332
# 180
# there is NO water shortage in the tank

# %%
from typing_extensions import final
import pandas as pd
import matplotlib.pyplot as plt
#dataset
df = pd.read_csv('/content/global_water_consumption_2000_2025.csv')

year = df['Year']
water_consumption = df['Total Water Consumption (Billion m3)']

tank_capacity = 500
#average water consumed
average_water_consumed = sum(water_consumption)/len(water_consumption)
print("\n average water consumed =", average_water_consumed)

# total water consumed in a day
print("total water consumed in a day ")
for i in range(len(water_consumption)):
  print(day[i],water_consumption[i])


# water usage increased
count = []  # create empty list first
l = len(water_consumption)
for i in range((l - 1)):
    count.append(abs(water_consumption[i + 1] - water_consumption[i]))
    print(count[i])

#sum of daily incresed water

total = sum(count)
average = total / len(count)

print("Sum of daily incresd water:", total)
print("Average of daily incresed water :", average)

# predictions
final_value = water_consumption[l-1]
print(final_value)
final_value = final_value + average
if (final_value < tank_capacity):
  print("there is NO water shortage in the tank")
else:
  print("there is water shortage in the tank")



plt.plot(day, water_consumption)

plt.xlabel("Day")
plt.ylabel("Water Consumed")
plt.title("Water Consumption Over Days")

plt.show()
# Out:
#  average water consumed = 65.81275128205128
# total water consumed in a day
# 1 586.04
# 2 590.09
# 3 600.0
# 4 610.45
# 5 617.08
# 6 625.46
# 7 632.79
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_966/2347762905.py in <cell line: 0>()
#      16 print("total water consumed in a day ")
#      17 for i in range(len(water_consumption)):
# ---> 18   print(day[i],water_consumption[i])
#      19
#      20
#
# IndexError: list index out of range

# %%
from typing_extensions import final
import pandas as pd
import matplotlib.pyplot as plt
#dataset
df = pd.read_csv('/content/global_water_consumption_2000_2025.csv')

year = df['Year']
water_consumption = df['Total Water Consumption (Billion m3)']
country = df['Country']
tank_capacity = 500
#average water consumed
average_water_consumed = sum(water_consumption)/len(water_consumption)
print("\n average water consumed =", average_water_consumed)

# total water consumed in a day
#print("total water consumed in a day ")
#for i in range(len(water_consumption)-1):
  #print(year[i],water_consumption[i])


# water usage increased
count = []  # create empty list first
l = len(water_consumption)
for i in range((l - 1)):
    count.append(abs(water_consumption[i + 1] - water_consumption[i]))
    #print(count[i])

#sum of daily incresed water

total = sum(count)
average = total / len(count)

print("Sum of daily incresd water:", total)
print("Average of daily incresed water :", average)

# predictions
final_value = water_consumption[l-1]
print(" the final valuer in the data ",final_value)
final_value = final_value + average
if (final_value < tank_capacity):
  print("there is NO water shortage in the tank")
else:
  print("there is water shortage in the tank")



plt.plot(year, water_consumption)

plt.xlabel("Day")
plt.ylabel("Water Consumed")
plt.title("Water Consumption Over Days")

plt.show()


plt.figure(figsize=(20, 30))

plt.barh(country, water_consumption)

plt.xlabel("Water Consumed")
plt.ylabel("Country")
plt.title("Water Consumption of All Countries")

plt.tight_layout()
plt.show()
# Out:
#  average water consumed = 65.81275128205128
# Sum of daily incresd water: 9687.849999999997
# Average of daily incresed water : 2.4847012054372906
#  the final valuer in the data  38.45
# there is NO water shortage in the tank
